# %% [markdown]
# # Data World Xcrap 🌍

# %% [markdown]
# The need and importance of extracting data from the web is becoming increasingly loud and clear.
#
# Every few day, I find myself in a situation where we need to extract data from the web.

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
import bs4 as bs
import urllib.request

source = urllib.request.urlopen('https://www.saude.mg.gov.br/component/search/?all=&exact=covid-19&any=&none=&created=&modified=&area=stories').read()

# %%
soup = bs.BeautifulSoup(source,'lxml')

# %%
# title of the page
print(soup.title)

# get attributes:
print(soup.title.name)

# get values:
print(soup.title.string)

# beginning navigation:
print(soup.title.parent.name)

# getting specific values:
print(soup.p)
# Out:
# <title>Buscar | Secretaria de Estado de Saúde de Minas Gerais - SES</title>
# title
# Buscar | Secretaria de Estado de Saúde de Minas Gerais - SES
# head
# <p>
# O Comitê Extraordinário Covid-19, que se reúne semanalmente para avaliar o avanço da pandemia do coronavírus no estado, suspendeu, na macrorregião de Saúde Leste do Sul, os protocolos da onda amarela do plano Minas Consciente. O programa foi criado pelo Governo de Minas para promover a retomada econômica gradual e coordenada nas cidades mineiras, sugerindo medidas que preservem a saúde dos mineiros.
#
# A ...</p>

# %%
print(soup.find_all('p'))
# Out:
# [<p>
# O Comitê Extraordinário Covid-19, que se reúne semanalmente para avaliar o avanço da pandemia do coronavírus no estado, suspendeu, na macrorregião de Saúde Leste do Sul, os protocolos da onda amarela do plano Minas Consciente. O programa foi criado pelo Governo de Minas para promover a retomada econômica gradual e coordenada nas cidades mineiras, sugerindo medidas que preservem a saúde dos mineiros.
#
# A ...</p>, <p>
# O secretário adjunto de Estado de Saúde de Minas Gerais, Marcelo Cabral, e o chefe de Gabinete da SES-MG, João Pinho, concederam coletiva no início da tarde desta quarta-feira (24/6), quando apresentaram o cenário epidemiológico da covid-19 em Minas, bem como as ações do Governo do Estado na prevenção e enfrentamento ao coronavírus. No Boletim Epidemiológico de hoje, foi confirmada a morte de uma criança ...</p>, <p>
# ...

# %%
for paragraph in soup.find_all('p'):
    print(paragraph.string)
    print(str(paragraph.text))
# Out:
# O Comitê Extraordinário Covid-19, que se reúne semanalmente para avaliar o avanço da pandemia do coronavírus no estado, suspendeu, na macrorregião de Saúde Leste do Sul, os protocolos da onda amarela do plano Minas Consciente. O programa foi criado pelo Governo de Minas para promover a retomada econômica gradual e coordenada nas cidades mineiras, sugerindo medidas que preservem a saúde dos mineiros.
#
# A ...
#
# O Comitê Extraordinário Covid-19, que se reúne semanalmente para avaliar o avanço da pandemia do coronavírus no estado, suspendeu, na macrorregião de Saúde Leste do Sul, os protocolos da onda amarela do plano Minas Consciente. O programa foi criado pelo Governo de Minas para promover a retomada econômica gradual e coordenada nas cidades mineiras, sugerindo medidas que preservem a saúde dos mineiros.
#
# A ...
#
# ...

# %%
for url in soup.find_all('a'):
    print(url.get('href'))
# Out:
# #increase-font
# #decrease-font
# #reset-font
# #high-contrast
# #low-contrast
# #navigation-start
# #content
# /ajuda
# /mapa-do-sitio
# /fale-conosco
# /acessibilidade
# /transparencia
# /component/gmg/stories?format=feed
# https://www.facebook.com/SaudeMG
# https://twitter.com/saudemg
# http://www.youtube.com/user/saudemg
# https://www.flickr.com/photos/saudemg2/sets/
# https://instagram.com/saudemg/
# http://blog.saude.mg.gov.br/
# https://www.saude.mg.gov.br/
# #
# #
# /cidadao/banco-de-noticias
# http://blog.saude.mg.gov.br
# /cidadao/campanhas/aids
# http://www.saude.mg.gov.br/aedes
# http://www.saude.mg.gov.br/gripe
# http://www.saude.mg.gov.br/saudedamulher
# http://www.saude.mg.gov.br/sus
# http://www.saude.mg.gov.br/tuberculose
# http://www.saude.mg.gov.br/vacinacao
# http://www.saude.mg.gov.br/vidasaudavel
# http://www.saude.mg.gov.br/sexoseguro
# http://www.saude.mg.gov.br/medicacaosegura
# ...

# %%
nav = soup.nav
for url in nav.find_all('a'):
    print(url.get('href'))

# %%
body = soup.body
for paragraph in body.find_all('p'):
    print(paragraph.text)
# Out:
# O Comitê Extraordinário Covid-19, que se reúne semanalmente para avaliar o avanço da pandemia do coronavírus no estado, suspendeu, na macrorregião de Saúde Leste do Sul, os protocolos da onda amarela do plano Minas Consciente. O programa foi criado pelo Governo de Minas para promover a retomada econômica gradual e coordenada nas cidades mineiras, sugerindo medidas que preservem a saúde dos mineiros.
#
# A ...
#
# O secretário adjunto de Estado de Saúde de Minas Gerais, Marcelo Cabral, e o chefe de Gabinete da SES-MG, João Pinho, concederam coletiva no início da tarde desta quarta-feira (24/6), quando apresentaram o cenário epidemiológico da covid-19 em Minas, bem como as ações do Governo do Estado na prevenção e enfrentamento ao coronavírus. No Boletim Epidemiológico de hoje, foi confirmada a morte de uma criança ...
#
# ...

# %%
for div in soup.find_all('div', class_='content'):
    print(div.text)
# Out:
#       Banco de notícias
#
# Onda amarela do plano Minas Consciente será suspensa para conter avanço da pandemia no estado
#
#
#       25 de Junho de 2020
#
#
# O Comitê Extraordinário Covid-19, que se reúne semanalmente para avaliar o avanço da pandemia do coronavírus no estado, suspendeu, na macrorregião de Saúde Leste do Sul, os protocolos da onda amarela do plano Minas Consciente. O programa foi criado pelo Governo de Minas para promover a retomada econômica gradual e coordenada nas cidades mineiras, sugerindo medidas que preservem a saúde dos mineiros.
#
# A ...
#
#
#
#
#
#       Banco de notícias
#
# Saúde reforça isolamento como principal forma de controle da covid-19
#
#
#       24 de Junho de 2020
#
#
# ...

# %%
#scrapping specifically with a table example
table = soup.table

#find the table rows within the table
table_rows = table.find_all('tr')

# iterate through the rows,find the td tags, and then print out each of the table data tags:
for tr in table_rows:
    td = tr.find_all('td')
    row = [i.text for i in td]
    print(row)

# %%
soup = bs.BeautifulSoup(source,'lxml')
for div in soup.find_all('div', class_='content'):
  for url in div.find_all('a'):
      print(url.get('href'))
# Out:
# /component/gmg/story/13029-onda-amarela-do-plano-minas-consciente-sera-suspensa-para-conter-avanco-da-pandemia-no-estado
# /component/gmg/story/13019-saude-reforca-isolamento-como-principal-forma-de-controle-da-covid-19
# /component/gmg/story/13013-conheca-o-rt-pcr-em-tempo-real-metodo-utilizado-para-o-diagnostico-de-covid-19
# /component/gmg/story/13012-secretario-reforca-ampliacao-da-assistencia-para-o-enfrentamento-da-pandemia
# /component/gmg/story/13027-pouso-alegre-sera-atendida-pelo-medicamento-em-casa
# /component/gmg/story/13027-pouso-alegre-sera-atendida-pelo-medicamento-em-casa
# /component/gmg/story/13026-informe-epidemiologico-coronavirus-25-06-2020
# /component/gmg/story/13026-informe-epidemiologico-coronavirus-25-06-2020
# /component/gmg/story/13025-regional-de-unai-realiza-reuniao-sobre-a-implementacao-do-painel-covid-19-mg
# /component/gmg/story/13025-regional-de-unai-realiza-reuniao-sobre-a-implementacao-do-painel-covid-19-mg
# ...

# %%
soup = bs.BeautifulSoup(source,'lxml')
for div in soup.find_all('div', class_='content'):
  for url in div.find_all('a'):
      print(url.text)
# Out:
# Onda amarela do plano Minas Consciente será suspensa para conter avanço da pandemia no estado
# Saúde reforça isolamento como principal forma de controle da covid-19
# Conheça o RT-PCR em tempo real, método utilizado para o diagnóstico de Covid-19
# Secretário reforça ampliação da assistência para o enfrentamento da pandemia
# Pouso Alegre será atendida pelo “Medicamento em Casa”
#
#
# Informe Epidemiológico Coronavírus - 25/06/2020
#
#
# Regional de Unaí realiza reunião sobre a implementação do Painel Covid-19-MG
#
#
# Coletiva virtual sobre os desdobramentos da covid-19 em Minas Gerais
#
#
# População indígena pauta reunião entre Regional de Saúde de Januária e município de São João das Missões
# Combate à pandemia exige expertise no manejo de leitos hospitalares
#
#
# Secretários se reúnem com prefeitos da Granbel
#
#
# Informe Epidemiológico Coronavírus 24/06/2020
#
#
#  Comitê Leste do Sul discute cenário da pandemia na macrorregião
#
#
# ...

# %%
soup = bs.BeautifulSoup(source,'xml')
for url in soup.find_all('loc'):
    print(url.text)

# %%
soup = bs.BeautifulSoup(source,'lxml')

js_test = soup.find('p', class_='jstest')

print(js_test.text)
